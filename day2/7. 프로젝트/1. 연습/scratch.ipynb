# %% [markdown]
# # 탐색 노트북
#
# 이 노트북은 탐색 전용입니다. EDA, 전처리 아이디어, 모델 파라미터 확인 등을 자유롭게 셀 단위로 실행해보세요.
#
# - 모델을 실제로 학습(fit)시키는 작업은 `experiments/`에 스크립트로 남깁니다.
# - 모델 학습이 없는 EDA/전처리 결과를 기록하고 싶으면 "이걸로 기록해줘", "대시보드에 반영해줘"처럼 요청하세요.
# - 자세한 규칙은 `AGENTS.md`를 참고하세요.
